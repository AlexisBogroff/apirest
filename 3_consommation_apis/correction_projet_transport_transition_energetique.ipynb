# %% [markdown]
# # French Transports
# - [> Portail API](https://transport.data.gouv.fr/swaggerui#/)
# - [> GTFS](https://transport.data.gouv.fr/explore/gtfs-stops)

# %%
import requests

def call_api(uri='api/datasets', domain='https://transport.data.gouv.fr/'):
    url = domain + uri
    headers = {
        'accept': 'application/json',
        'x-csrf-token': 'KWlXAyEyLgAhEyYHQE8kZgE_Mg82HiIbZPc7Qcc9GQq5m5iP8LwJfxFW'
    }
    response = requests.get(url, headers=headers)
    return response.json()

# %% [markdown]
# ## Extract list of databases

# %%
databases = call_api()

# %%
# Extract main data for each database

import pandas as pd
import numpy as np

def try_get(database, key):
    """ Tries to get the value of a key in a dictionary, if it fails, it returns None """
    try:
        value = database[key]
    except:
        value = np.nan
    return value

def try_get_resources(database, key):
    """ Extracts specific data from the resources of the database """
    values = [resource[key] for resource in database['resources']]
    return values


data = {'title': [], 'id': [], 'url': [], 'types': []}


for database in databases:
    data['title'].append(try_get(database, 'title'))
    data['id'].append(try_get(database, 'id'))
    data['url'].append(try_get_resources(database, 'url'))
    data['types'].append(try_get_resources(database, 'format'))

df = pd.DataFrame(data)
df
# Out:
#                                                  title  \
# 0    Base Nationale des Zones à Faibles Émissions (...
# 1    Base nationale consolidée des lieux de covoitu...
# 2    Base nationale des lieux de stationnement hors...
# 3                      Base nationale des parcs relais
# 4                                Réseau urbain Marinéo
# ..                                                 ...
# 491                                Réseau urbain Bibus
# 492            Réseau de transport en Haute-Tarentaise
# 493                               Réseau urbain Tisséo
# 494                               Réseau urbain ilévia
# 495                                 Réseau urbain Stan
#
#                            id  \
# 0    625438b890bf88454b283a55
# 1    5d6eaffc8b4c417cdc452ac3
# 2    5ea1add4a5a7dac3af82310a
# 3    63692c99da0527c2b541e02b
# 4    5b0d18ed88ee3836341f603d
# ..                        ...
# 491  55ffbe0888ee387348ccb97d
# 492  637fa2bfd27b2c34c0515628
# 493  56b0c2fba3a7294d39b88a86
# 494  58b69b59a3a7295a7d8251db
# 495  5aa94714c751df666fefc80f
#
#                                                    url  \
# 0    [https://www.data.gouv.fr/fr/datasets/r/b18336...
# 1    [https://www.data.gouv.fr/fr/datasets/r/46362a...
# 2    [https://www.data.gouv.fr/fr/datasets/r/e32f76...
# 3    [https://www.data.gouv.fr/fr/datasets/r/e3fb44...
# 4    [https://www.data.gouv.fr/fr/datasets/r/ecef73...
# ..                                                 ...
# 491  [https://www.data.gouv.fr/fr/datasets/r/f7cbc4...
# 492  [https://www.data.gouv.fr/fr/datasets/r/ac5f06...
# 493  [https://www.data.gouv.fr/fr/datasets/r/f2c421...
# 494  [https://www.data.gouv.fr/fr/datasets/r/754b70...
# 495  [https://www.data.gouv.fr/fr/datasets/r/22ff00...
#
#                                        types
# 0                    [csv, geojson, geojson]
# 1                            [csv, csv, shp]
# 2                                      [csv]
# 3                                      [csv]
# 4                   [gtfs-rt, gtfs-rt, GTFS]
# ..                                       ...
# 491  [gtfs-rt, SIRI, gtfs-rt, GTFS, gtfs-rt]
# 492                                   [GTFS]
# 493                                   [GTFS]
# 494                     [GTFS, gtfs-rt, pdf]
# 495                                   [GTFS]
#
# [496 rows x 4 columns]

# %% [markdown]
# ## Investigation of each database

# %%
# By index
index = 3
id = df.iloc[index]['id']
call_api(f'/api/datasets/{id}')
# Out:
# {'aom': {'name': None},
#  'community_resources': [],
#  'covered_area': {'country': {'name': 'France'},
#   'name': 'France',
#   'type': 'country'},
#  'created_at': '2022-11-07',
#  'datagouv_id': '63692c99da0527c2b541e02b',
#  'history': [{'resource_id': 79896,
#    'payload': {'content_hash': '0954dfcb6f99c52e2d0dc4f1cf415c3e0df3d644b30f17ccbb6ae680dca9af62',
#     'dataset_id': 819,
#     'download_datetime': '2023-04-05T05:33:09.229482Z',
#     'filename': '79896/79896.20230405.053309.229482.csv',
#     'filesize': 52415,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '52415',
#      'content-type': 'text/csv',
#      'etag': '"642d074c-ccbf"',
#      'expires': 'Fri, 05 May 2023 05:33:09 GMT',
#      'last-modified': 'Wed, 05 Apr 2023 05:29:48 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20230405.053309.229482.csv',
#     'resource_latest_url': 'https://www.data.gouv.fr/fr/datasets/r/e3fb44fc-8b55-4c5e-8e57-83ebdbc6f4d4',
#     'resource_url': 'https://static.data.gouv.fr/resources/base-nationale-des-parkings-relais-experimentation/20230405-072948/basep-r-05012023-3-.csv',
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'basep-r-05012023-3-.csv',
#     'uuid': 'cb1c1b2a-5445-4f43-aed6-15687843ca65'},
#    'last_up_to_date_at': '2023-12-18T18:09:14.593515Z',
#    'inserted_at': '2023-04-05T05:33:09.329697Z',
#    'updated_at': '2023-12-18T18:09:14.593553Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': '3a5d5d7b00b9c94c4e3c138a795cd8bbe4949a926e2d9c98f3257c773cfc24fe',
#     'dataset_id': 819,
#     'download_datetime': '2023-01-05T15:50:39.447570Z',
#     'filename': '79896/79896.20230105.155039.447570.csv',
#     'filesize': 3504736,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '3504736',
#      'content-type': 'text/csv',
#      'etag': '"63b6f1cd-357a60"',
#      'expires': 'Sat, 04 Feb 2023 15:50:39 GMT',
#      'last-modified': 'Thu, 05 Jan 2023 15:50:37 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20230105.155039.447570.csv',
#     'resource_latest_url': 'https://www.data.gouv.fr/fr/datasets/r/e3fb44fc-8b55-4c5e-8e57-83ebdbc6f4d4',
#     'resource_url': 'https://static.data.gouv.fr/resources/base-nationale-des-parkings-relais-experimentation/20230105-165037/basep-r-05012023.csv',
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'Base consolidée P+R - 05012023',
#     'uuid': '2074c3cb-903d-4f4b-922c-90b009d0849f'},
#    'last_up_to_date_at': '2023-04-05T00:20:21.225160Z',
#    'inserted_at': '2023-01-05T15:50:41.048900Z',
#    'updated_at': '2023-04-05T00:20:21.225186Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': '4b7e6b9e4bd14a19d925cd05b8e280afc9ef1f133644290a2eab9ba5e0b04a37',
#     'dataset_id': 819,
#     'download_datetime': '2022-11-17T09:12:59.824271Z',
#     'filename': '79896/79896.20221117.091259.824271.csv',
#     'filesize': 44616,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '44616',
#      'content-type': 'text/csv',
#      'etag': '"637501bc-ae48"',
#      'expires': 'Sat, 17 Dec 2022 09:12:59 GMT',
#      'last-modified': 'Wed, 16 Nov 2022 15:29:00 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20221117.091259.824271.csv',
#     'resource_metadata': None,
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'Base consolidée P+R - 16/11/2022',
#     'uuid': '5583a1db-d270-4fed-8640-96569ea80622'},
#    'last_up_to_date_at': '2023-01-05T12:19:57.328803Z',
#    'inserted_at': '2022-11-17T09:13:00.094017Z',
#    'updated_at': '2023-01-05T12:19:57.328845Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': '4b7e6b9e4bd14a19d925cd05b8e280afc9ef1f133644290a2eab9ba5e0b04a37',
#     'dataset_id': 819,
#     'download_datetime': '2022-11-17T09:12:59.848329Z',
#     'filename': '79896/79896.20221117.091259.848329.csv',
#     'filesize': 44616,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '44616',
#      'content-type': 'text/csv',
#      'etag': '"637501bc-ae48"',
#      'expires': 'Sat, 17 Dec 2022 09:12:59 GMT',
#      'last-modified': 'Wed, 16 Nov 2022 15:29:00 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20221117.091259.848329.csv',
#     'resource_metadata': None,
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'Base consolidée P+R - 16/11/2022',
#     'uuid': 'cf6d2c57-f894-45c4-bc6d-5530fcf16242'},
#    'last_up_to_date_at': '2022-11-17T09:12:59.939098Z',
#    'inserted_at': '2022-11-17T09:12:59.939187Z',
#    'updated_at': '2022-11-17T09:12:59.939187Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': 'c324b1943b375b20008cefba0ea981059665ed0e25c50f17460c3666e55e574c',
#     'dataset_id': 819,
#     'download_datetime': '2022-11-07T18:08:44.370855Z',
#     'filename': '79896/79896.20221107.180844.370855.csv',
#     'filesize': 39051,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '39051',
#      'content-type': 'text/csv',
#      'etag': '"63692f17-988b"',
#      'expires': 'Wed, 07 Dec 2022 18:08:44 GMT',
#      'last-modified': 'Mon, 07 Nov 2022 16:15:19 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20221107.180844.370855.csv',
#     'resource_metadata': None,
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'base-parc-relais-vf.csv',
#     'uuid': '3ec9355f-bf7c-4d78-bfb7-3b582edc7570'},
#    'last_up_to_date_at': '2022-11-16T12:08:38.618403Z',
#    'inserted_at': '2022-11-07T18:08:44.401111Z',
#    'updated_at': '2022-11-16T12:08:38.618467Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': '012ecc1052744c910ea3630d1774ee5d77d52c77c2ec6c6e0b66508e65824058',
#     'dataset_id': 819,
#     'download_datetime': '2022-11-07T16:10:10.618455Z',
#     'filename': '79896/79896.20221107.161010.618455.csv',
#     'filesize': 15756299,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '15756299',
#      'content-type': 'text/csv',
#      'etag': '"63692dde-f06c0b"',
#      'expires': 'Wed, 07 Dec 2022 16:10:09 GMT',
#      'last-modified': 'Mon, 07 Nov 2022 16:10:06 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20221107.161010.618455.csv',
#     'resource_metadata': None,
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'Base nationale des parcs relais',
#     'uuid': 'dc45e03c-33c3-46d0-a9bb-0e2e734158ce'},
#    'last_up_to_date_at': '2022-11-07T16:10:11.483344Z',
#    'inserted_at': '2022-11-07T16:10:11.483420Z',
#    'updated_at': '2022-11-07T16:10:11.483420Z'},
#   {'resource_id': 79896,
#    'payload': {'content_hash': '572295bef5d8b4e183a2c3b0ff1902900ebd3bab87d05d8730ecdc3bea6b1223',
#     'dataset_id': 819,
#     'download_datetime': '2022-11-07T16:07:33.322645Z',
#     'filename': '79896/79896.20221107.160733.322645.xlsx',
#     'filesize': 38734535,
#     'format': 'xlsx',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '38734535',
#      'content-type': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'etag': '"63692cc7-24f0ac7"',
#      'expires': 'Wed, 07 Dec 2022 16:07:31 GMT',
#      'last-modified': 'Mon, 07 Nov 2022 16:05:27 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/79896/79896.20221107.160733.322645.xlsx',
#     'resource_metadata': None,
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'Base nationale des parcs relais',
#     'uuid': 'f3e1be56-67fa-4c02-a258-37b168dcda89'},
#    'last_up_to_date_at': '2022-11-07T16:08:02.327692Z',
#    'inserted_at': '2022-11-07T16:07:34.672239Z',
#    'updated_at': '2022-11-07T16:08:02.327743Z'}],
#  'id': '63692c99da0527c2b541e02b',
#  'licence': 'lov2',
#  'page_url': 'https://transport.data.gouv.fr/datasets/base-nationale-des-parkings-relais-experimentation',
#  'publisher': {'name': "Point d'Accès National transport.data.gouv.fr",
#   'type': 'organization'},
#  'resources': [{'conversions': {},
#    'datagouv_id': 'e3fb44fc-8b55-4c5e-8e57-83ebdbc6f4d4',
#    'filesize': 52415,
#    'format': 'csv',
#    'id': 79896,
#    'is_available': True,
#    'original_url': 'https://static.data.gouv.fr/resources/base-nationale-des-parkings-relais-experimentation/20230405-072948/basep-r-05012023-3-.csv',
#    'page_url': 'https://transport.data.gouv.fr/resources/79896',
#    'title': 'basep-r-05012023-3-.csv',
#    'type': 'main',
#    'updated': '2023-04-05T07:29:50.090000Z',
#    'url': 'https://www.data.gouv.fr/fr/datasets/r/e3fb44fc-8b55-4c5e-8e57-83ebdbc6f4d4'}],
#  'slug': 'base-nationale-des-parkings-relais-experimentation',
#  'title': 'Base nationale des parcs relais',
#  'type': 'private-parking',
#  'updated': '2023-04-05T07:29:50.090000Z'}

# %% [markdown]
# ## Find a specific database

# %%
ma_parkings = df['title'].str.contains('transport')
df[ma_parkings]
# Out:
#                                                  title  \
# 130  Réseau de transport routier national métropoli...
# 487                      Arrêts de transport en France
# 492            Réseau de transport en Haute-Tarentaise
#
#                            id  \
# 130  5df7bb6a634f410f690ae7ea
# 487  651d2ece3af956b8dd0d7648
# 492  637fa2bfd27b2c34c0515628
#
#                                                    url   types
# 130  [https://www.data.gouv.fr/fr/datasets/r/2f4bfd...  [gpkg]
# 487  [https://www.data.gouv.fr/fr/datasets/r/69cf54...   [csv]
# 492  [https://www.data.gouv.fr/fr/datasets/r/ac5f06...  [GTFS]

# %%
# By id
id = '651d2ece3af956b8dd0d7648'
call_api(f'/api/datasets/{id}')
# Out:
# {'aom': {'name': None},
#  'community_resources': [],
#  'covered_area': {'country': {'name': 'France'},
#   'name': 'France',
#   'type': 'country'},
#  'created_at': '2023-10-04',
#  'datagouv_id': '651d2ece3af956b8dd0d7648',
#  'history': [{'resource_id': 81333,
#    'payload': {'content_hash': '6f65df223c9588ed55212858d189b36dabfdeb765643a713bf39267332e1c137',
#     'dataset_id': 977,
#     'download_datetime': '2023-10-04T12:59:13.887497Z',
#     'filename': '81333/81333.20231004.125913.887497.csv',
#     'filesize': 90253346,
#     'format': 'csv',
#     'http_headers': {'content-disposition': 'attachment',
#      'content-length': '90253346',
#      'content-type': 'text/csv',
#      'etag': '"651d2ee8-5612822"',
#      'expires': 'Fri, 03 Nov 2023 12:59:12 GMT',
#      'last-modified': 'Wed, 04 Oct 2023 09:22:48 GMT'},
#     'latest_schema_version_to_date': None,
#     'permanent_url': 'https://transport-data-gouv-fr-resource-history-prod.cellar-c2.services.clever-cloud.com/81333/81333.20231004.125913.887497.csv',
#     'resource_latest_url': 'https://www.data.gouv.fr/fr/datasets/r/69cf54c6-6591-4920-b1d6-2a5292964606',
#     'resource_url': 'https://static.data.gouv.fr/resources/arrets-de-transport-en-france/20231004-092240/export.csv',
#     'schema_name': None,
#     'schema_version': None,
#     'title': 'points-d-arret-gtfs.csv',
#     'uuid': '29ff115b-35c5-4dc6-9082-336ac3f41d44'},
#    'last_up_to_date_at': '2023-12-18T18:07:12.540922Z',
#    'inserted_at': '2023-10-04T12:59:15.298418Z',
#    'updated_at': '2023-12-18T18:07:12.540957Z'}],
#  'id': '651d2ece3af956b8dd0d7648',
#  'licence': 'lov2',
#  'page_url': 'https://transport.data.gouv.fr/datasets/arrets-de-transport-en-france',
#  'publisher': {'name': "Point d'Accès National transport.data.gouv.fr",
#   'type': 'organization'},
#  'resources': [{'conversions': {},
#    'datagouv_id': '69cf54c6-6591-4920-b1d6-2a5292964606',
#    'filesize': 90253346,
#    'format': 'csv',
#    'id': 81333,
#    'is_available': True,
#    'original_url': 'https://static.data.gouv.fr/resources/arrets-de-transport-en-france/20231004-092240/export.csv',
#    'page_url': 'https://transport.data.gouv.fr/resources/81333',
#    'title': 'points-d-arret-gtfs.csv',
#    'type': 'main',
#    'updated': '2023-10-04T09:24:20.170000Z',
#    'url': 'https://www.data.gouv.fr/fr/datasets/r/69cf54c6-6591-4920-b1d6-2a5292964606'}],
#  'slug': 'arrets-de-transport-en-france',
#  'title': 'Arrêts de transport en France',
#  'type': 'informations',
#  'updated': '2023-10-04T09:24:20.170000Z'}
